# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import vectorbt as bt

# %%
btc = pd.read_csv('/home/bhanu430/Downloads/archive//btc_15m_data_2018_to_2024-2024-12-10.csv')
btc.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 btc = pd.read_csv('/home/bhanu430/Downloads/archive//btc_15m_data_2018_to_2024-2024-12-10.csv')
#       2 btc.head()
#
# ...

# %%
btc = btc[['Open time','Open', 'High', 'Low', 'Close', 'Volume']]
btc.set_index('Open time', inplace=True)
btc.index = pd.to_datetime(btc.index)
btc.head()
# Out:
#                          Open      High       Low     Close      Volume
# Open time
# 2018-01-01 00:00:00  13715.65  13715.65  13400.01  13556.15  123.616013
# 2018-01-01 00:15:00  13533.75  13550.87  13402.00  13521.12   98.136430
# 2018-01-01 00:30:00  13500.00  13545.37  13450.00  13470.41   79.904037
# 2018-01-01 00:45:00  13494.65  13690.87  13450.00  13529.01  141.699719
# 2018-01-01 01:00:00  13528.99  13571.74  13402.28  13445.63   72.537533

# %%
#plotting the closing price
plt.plot(btc['Close'].iloc[-50 : -1 ], label='BTC')

# %%
# btc.describe()
# btc.info()

# %%
btc['bullish_hammer'] = ((((btc['High'] - btc['Low']) > 3 * (btc['Open'] - btc['Close'])) &
                      ((btc['Close'] - btc['Low'])/(0.001 + btc['High'] - btc['Low']) > 0.6) &
                      ((btc['Open'] - btc['Low']) < 0.6 * (btc['High'] - btc['Low'] + 0.001)))
                      ).astype(int)

# %%
# Out:
#                          Open      High       Low     Close      Volume  \
# Open time
# 2018-01-01 00:00:00  13715.65  13715.65  13400.01  13556.15  123.616013
# 2018-01-01 00:15:00  13533.75  13550.87  13402.00  13521.12   98.136430
# 2018-01-01 00:30:00  13500.00  13545.37  13450.00  13470.41   79.904037
# 2018-01-01 00:45:00  13494.65  13690.87  13450.00  13529.01  141.699719
# 2018-01-01 01:00:00  13528.99  13571.74  13402.28  13445.63   72.537533
# ...                       ...       ...       ...       ...         ...
# 2024-12-09 23:30:00  97425.20  97469.00  97190.70  97430.01  310.918480
# 2024-12-09 23:45:00  97430.00  97482.74  97260.00  97276.47  265.181280
# 2024-12-10 00:00:00  97276.48  97309.00  97000.00  97297.17  547.402610
# 2024-12-10 00:15:00  97297.18  97600.00  97168.00  97573.03  411.947720
# 2024-12-10 00:30:00  97573.03  98138.00  97480.01  97707.69  546.517970
#
#                      bullish_hammer
# Open time
# 2018-01-01 00:00:00               0
# ...
