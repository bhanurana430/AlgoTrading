# %%
#Import library
import numpy as np
import pandas as pd
import vectorbt as bt
import yfinance as yf
import pandas_ta as ta

# %%
#Get Data
btc = yf.download('BTC-USD', start='2024-10-20', end='2025-01-01', interval='1h')
print(btc.head())
btc.columns = ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']
btc = btc.asfreq('h')
btc.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
# Price                             Close          High           Low  \
# Ticker                          BTC-USD       BTC-USD       BTC-USD
# Datetime
# 2024-10-20 00:00:00+00:00  68229.203125  68418.773438  68229.203125
# 2024-10-20 01:00:00+00:00  68150.835938  68233.750000  68147.601562
# 2024-10-20 02:00:00+00:00  68161.031250  68202.617188  68133.117188
# 2024-10-20 03:00:00+00:00  68178.179688  68183.195312  68113.890625
# 2024-10-20 04:00:00+00:00  68223.242188  68288.992188  68169.851562
#
# Price                              Open  Volume
# Ticker                          BTC-USD BTC-USD
# Datetime
# 2024-10-20 00:00:00+00:00  68366.562500       0
# 2024-10-20 01:00:00+00:00  68222.632812       0
# 2024-10-20 02:00:00+00:00  68156.867188       0
# 2024-10-20 03:00:00+00:00  68163.093750       0
# 2024-10-20 04:00:00+00:00  68171.140625       0
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 4
#       2 btc = yf.download('BTC-USD', start='2024-10-20', end='2025-01-01', interval='1h')
#       3 print(btc.head())
# ----> 4 btc.columns = ['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume']
#       5 btc = btc.asfreq('h')
#       6 btc.tail()
#
# File c:\Users\bhanu\anaconda3\Lib\site-packages\pandas\core\generic.py:6313, in NDFrame.__setattr__(self, name, value)
#    6311 try:
#    6312     object.__getattribute__(self, name)
# -> 6313     return object.__setattr__(self, name, value)
#    6314 except AttributeError:
#    6315     pass
#
# File properties.pyx:69, in pandas._libs.properties.AxisProperty.__set__()
#
# File c:\Users\bhanu\anaconda3\Lib\site-packages\pandas\core\generic.py:814, in NDFrame._set_axis(self, axis, labels)
#     809 """
#     810 This is called from the cython code when we set the `index` attribute
#     811 directly, e.g. `series.index = [1, 2, 3]`.
#     812 """
#     813 labels = ensure_index(labels)
# --> 814 self._mgr.set_axis(axis, labels)
#     815 self._clear_item_cache()
#
# File c:\Users\bhanu\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:238, in BaseBlockManager.set_axis(self, axis, new_labels)
#     236 def set_axis(self, axis: AxisInt, new_labels: Index) -> None:
#     237     # Caller is responsible for ensuring we have an Index object.
# --> 238     self._validate_set_axis(axis, new_labels)
#     239     self.axes[axis] = new_labels
#
# File c:\Users\bhanu\anaconda3\Lib\site-packages\pandas\core\internals\base.py:98, in DataManager._validate_set_axis(self, axis, new_labels)
#      95     pass
#      97 elif new_len != old_len:
# ---> 98     raise ValueError(
#      99         f"Length mismatch: Expected axis has {old_len} elements, new "
#     100         f"values have {new_len} elements"
#     101     )
#
# ValueError: Length mismatch: Expected axis has 5 elements, new values have 6 elements

# %%
# Initial parameters
initial_capital = 100000
risk_per_trade = 0.02  # 2%sl_trail=True
stop_loss = 0.18  # 18%
take_profit = 0.40  # 40%

# %%
#Technical Indicators
btc['rsi']= ta.rsi(btc['Close'], length=14)
btc['ema_short'] = ta.ema(btc['Close'], length=20)
btc['ema_long'] = ta.ema(btc['Close'], length=50)
btc['vwap'] = ta.vwap(btc['High'], btc['Low'], btc['Close'], btc['Volume'])
bb = ta.bbands(btc['Close'], length=20, std=2)
adx_results = ta.adx(btc['High'], btc['Low'], btc['Close'], length=5)

# Assign to DataFrame
btc['adx'] = adx_results['ADX_5']  # ADX values
btc['a'] = adx_results['DMP_5']    # Positive Directional Movement
btc['b'] = adx_results['DMN_5']    # Negative Directional Movement

btc['bbl'] = bb['BBL_20_2.0']
btc['bbm'] = bb['BBM_20_2.0']
btc['bbu'] = bb['BBU_20_2.0']
# Out:
# /home/bhanu430/.local/lib/python3.12/site-packages/pandas_ta/overlap/vwap.py:23: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   vwap  = wp.groupby(wp.index.to_period(anchor)).cumsum()
# /home/bhanu430/.local/lib/python3.12/site-packages/pandas_ta/overlap/vwap.py:24: UserWarning: Converting to PeriodArray/Index representation will drop timezone information.
#   vwap /= volume.groupby(volume.index.to_period(anchor)).cumsum()

# %%
#Entry and Exit 
# btc['long_entry'] = ((btc['a'] > btc['b']) & (btc['rsi']<30)).astype(int)
btc['long_entry'] = ((btc['ema_short'] > btc['ema_long']) & (btc['rsi']<30)).astype(int)

# btc['long_exit'] = ((btc['Close']>btc['bbu'])).astype(int)

btc['short_entry'] = ((btc['ema_short'] < btc['ema_long']) & (btc['rsi']>70)).astype(int)
# btc['short_exit'] = (btc['rsi']<30).astype(int)

# %%
#Portfolio Construction
pf = bt.Portfolio.from_signals(btc['Close'], entries=btc['long_entry'], short_entries=btc['short_entry'],fees=0.001, slippage=0.001, sl_stop=0.04, sl_trail=True, upon_stop_exit='reverse')

# %%
#Returns
returns = pf.total_return()
print(returns)
# Out:
# 0.0644828023338988

# %%
#Stats
pf.stats()
# Out:
# Start                         2024-10-20 00:00:00+00:00
# End                           2024-12-31 23:00:00+00:00
# Period                                 73 days 00:00:00
# Start Value                                       100.0
# End Value                                     106.44828
# Total Return [%]                                6.44828
# Benchmark Return [%]                          36.980087
# Max Gross Exposure [%]                            100.0
# Total Fees Paid                                4.663518
# Max Drawdown [%]                              15.771699
# Max Drawdown Duration                  27 days 12:00:00
# Total Trades                                         21
# Total Closed Trades                                  20
# Total Open Trades                                     1
# Open Trade PnL                                -2.500883
# Win Rate [%]                                       40.0
# Best Trade [%]                                26.531703
# Worst Trade [%]                               -3.799587
# Avg Winning Trade [%]                          5.716901
# Avg Losing Trade [%]                          -2.766761
# Avg Winning Trade Duration              3 days 21:00:00
# Avg Losing Trade Duration               2 days 11:55:00
# Profit Factor                                   1.23838
# Expectancy                                     0.447458
# Sharpe Ratio                                    0.87352
# Calmar Ratio                                   2.325451
# Omega Ratio                                    1.029959
# Sortino Ratio                                  1.275567
# dtype: object

# %%
#Plots
pf.plot(
    subplots=['trades', 'orders', 'trade_pnl', 'cum_returns']
    )
# Out:
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6a75f805-83f5-429a-b26b-5c3ea7c6b3f1',
#               'x': array([datetime.datetime(2024, 10, 20, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 1, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 2, 0, tzinfo=datetime.timezone.utc),
#                           ...,
#                           datetime.datetime(2024, 12, 31, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 22, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 23, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([68229.203125 , 68150.8359375, 68161.03125  , ..., 93746.2421875,
#                           93254.0625   , 93460.421875 ]),
#               'yaxis': 'y'},
#              {'customdata': array([[0, 0, 0.0014131869412537445, 0.09990009990008275, 'Long'],
#                                    [1, 1, 0.0014103633909215694, 0.09610810040948721, 'Short'],
#                                    [2, 2, 0.0013334332135015426, 0.09332011509796014, 'Long'],
#                                    [3, 3, 0.0013307690112767646, 0.11805479585296702, 'Short'],
#                                    [4, 4, 0.0012518249959688654, 0.11433179789040637, 'Long'],
#                                    [5, 5, 0.001249323847125771, 0.11904114930974276, 'Short'],
#                                    [6, 6, 0.0012562194686026131, 0.11924951843618398, 'Long'],
#                                    [7, 7, 0.001253709539594416, 0.12063124218322503, 'Short'],
#                                    [8, 8, 0.001181915508892214, 0.11695848059969614, 'Long'],
#                                    [9, 9, 0.001179554039343978, 0.1167391823519089, 'Short'],
#                                    [10, 10, 0.0011330320420591053, 0.11427647873002829, 'Long'],
#                                    [11, 11, 0.0011307682417752707, 0.11022653730746783, 'Short'],
#                                    [12, 12, 0.0011003171232764298, 0.1086134895180035, 'Long'],
#                                    [13, 13, 0.001098118687465688, 0.11402132657487135, 'Short'],
#                                    [14, 14, 0.0012504466569784253, 0.1212954553938624, 'Long'],
#                                    [15, 15, 0.0012479482620593877, 0.11817074607971494, 'Short'],
#                                    [16, 16, 0.0011763409161085919, 0.11456571661314026, 'Long'],
#                                    [17, 17, 0.0011739905846078753, 0.11505638651724183, 'Short'],
#                                    [18, 18, 0.0012230492919531682, 0.11729387932691902, 'Long'],
#                                    [19, 19, 0.0012206056370241908, 0.11285381192581027, 'Short'],
#                                    [20, 20, 0.00113896639987096, 0.10884032322930184, 'Long']],
#                                   dtype=object),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'br>Direction: %{customdata[4]}'),
#               'legendgroup': '1',
#               'marker': {'color': '#4285F4',
#                          'line': {'color': 'rgb(11,84,205)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'square'},
#               'mode': 'markers',
#               'name': 'Entry',
#               'type': 'scatter',
#               'uid': '37973afb-0537-4bed-b5b1-2f5de1cd091d',
#               'x': array([datetime.datetime(2024, 10, 31, 15, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 3, 2, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 5, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 13, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 15, 20, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 25, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 27, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 27, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 4, 20, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 5, 19, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 6, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 9, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 11, 13, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 18, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 20, 15, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 22, 19, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 24, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 24, 15, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 26, 8, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 30, 13, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 14, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([ 70691.35510937,  68144.2109375 ,  69984.84375   ,  88711.7109375 ,
#                            91332.09375   ,  95284.4609375 ,  94927.296875  ,  96219.44985938,
#                            98956.71875   ,  98968.9140625 , 100859.        ,  97479.3359375 ,
#                            98711.078125  , 103833.3359375 ,  97001.703125  ,  94692.0234375 ,
#                            97391.59375   ,  98004.522375  ,  95902.82264062,  92457.2265625 ,
#                            95560.609375  ]),
#               'yaxis': 'y'},
#              {'customdata': array([[2, 2, 0.0013334332135015426, 0.11829114179061057, 24.759415435756143,
#                                     0.2653170263427572, 'Long', '8 days 07:00:00'],
#                                    [4, 4, 0.0012518249959688654, 0.11927946992898146, 4.7140607707402715,
#                                     0.04123140594061448, 'Long', '9 days 21:00:00'],
#                                    [5, 5, 0.001249323847125771, 0.11859493572911423, 0.2085774955787239,
#                                     0.0017521461846441797, 'Short', '1 days 21:00:00'],
#                                    [6, 6, 0.0012562194686026131, 0.12087274617157985, 1.3831054707770807,
#                                     0.011598415565234483, 'Long', '0 days 03:00:00'],
#                                    [12, 12, 0.0011003171232764298, 0.11424959749894514, 5.413244893913271,
#                                     0.04983952654440235, 'Long', '6 days 15:00:00'],
#                                    [13, 13, 0.001098118687465688, 0.10651938291755474, 7.281402947817596,
#                                     0.06386000905748374, 'Short', '2 days 11:00:00'],
#                                    [16, 16, 0.0011763409161085919, 0.1152867296333925, 0.4911605739951521,
#                                     0.004287151414184691, 'Long', '0 days 01:00:00'],
#                                    [17, 17, 0.0011739905846078753, 0.11258901081740537,
#                                     2.2397303024944866, 0.019466370970714002, 'Short', '1 days 17:00:00']],
#                                   dtype=object),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... '<br>Duration: %{customdata[7]}'),
#               'legendgroup': '2',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'square'},
#               'mode': 'markers',
#               'name': 'Exit - Profit',
#               'type': 'scatter',
#               'uid': '52eaded2-1f39-487d-9776-dac8cb1f1e6e',
#               'x': array([datetime.datetime(2024, 11, 13, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 25, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 27, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 27, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 18, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 20, 15, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 24, 15, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 26, 8, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([ 88711.7109375 ,  95284.4609375 ,  94927.296875  ,  96219.44985938,
#                           103833.3359375 ,  97001.703125  ,  98004.522375  ,  95902.82264062]),
#               'yaxis': 'y'},
#              {'customdata': array([[0, 0, 0.0014131869412537445, 0.09630050901891558, -3.795791490103325,
#                                     -0.03799587281593428, 'Long', '2 days 11:00:00'],
#                                    [1, 1, 0.0014103633909215694, 0.09870406154436016, -2.790773296832852,
#                                     -0.029037857214347398, 'Short', '2 days 12:00:00'],
#                                    [3, 3, 0.0013307690112767646, 0.12154192009750786, -3.726720960507725,
#                                     -0.03156772186662558, 'Short', '1 days 23:00:00'],
#                                    [7, 7, 0.001253709539594416, 0.12406298230382197, -3.6764343450986403,
#                                     -0.030476635062039386, 'Short', '7 days 03:00:00'],
#                                    [8, 8, 0.001181915508892214, 0.11697289442868948, -0.2195175460488577,
#                                     -0.0018768843860083636, 'Long', '0 days 23:00:00'],
#                                    [9, 9, 0.001179554039343978, 0.11896864085418284, -2.46516632549146,
#                                     -0.021116871609227525, 'Short', '0 days 22:00:00'],
#                                    [10, 10, 0.0011330320420591053, 0.11044721105583115,
#                                     -4.0539913639940135, -0.035475291232686196, 'Long', '3 days 00:00:00'],
#                                    [11, 11, 0.0011307682417752707, 0.1116193522551359,
#                                     -1.6146608372423992, -0.014648567184310943, 'Short',
#                                     '1 days 20:00:00'],
#                                    [14, 14, 0.0012504466569784253, 0.11840732414994458,
#                                     -3.127834023469165, -0.025786902017989707, 'Long', '2 days 04:00:00'],
#                                    [15, 15, 0.0012479482620593877, 0.12153967015949523,
#                                     -3.608634496030708, -0.030537460545407884, 'Short', '1 days 19:00:00'],
#                                    [18, 18, 0.0012230492919531682, 0.11307974548321927,
#                                     -4.444507468517525, -0.0378920664404798, 'Long', '4 days 05:00:00'],
#                                    [19, 19, 0.0012206056370241908, 0.1166418184805735, -4.017502185187873,
#                                     -0.035599171322887764, 'Short', '1 days 01:00:00']], dtype=object),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... '<br>Duration: %{customdata[7]}'),
#               'legendgroup': '3',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'square'},
#               'mode': 'markers',
#               'name': 'Exit - Loss',
#               'type': 'scatter',
#               'uid': '7cfaf5ca-eeee-4054-9655-008492554029',
#               'x': array([datetime.datetime(2024, 11, 3, 2, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 5, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 15, 20, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 4, 20, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 5, 19, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 6, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 9, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 11, 13, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 22, 19, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 24, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 30, 13, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 14, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([ 68144.2109375,  69984.84375  ,  91332.09375  ,  98956.71875  ,
#                            98968.9140625, 100859.       ,  97479.3359375,  98711.078125 ,
#                            94692.0234375,  97391.59375  ,  92457.2265625,  95560.609375 ]),
#               'yaxis': 'y'},
#              {'customdata': array([[20, 20, 0.00113896639987096, 0.0, -2.500883319158291,
#                                     -0.022977544029239114, 'Long', '0 days 10:00:00']], dtype=object),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... '<br>Duration: %{customdata[7]}'),
#               'legendgroup': '4',
#               'marker': {'color': '#FFAA00',
#                          'line': {'color': 'rgb(178,118,0)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'square'},
#               'mode': 'markers',
#               'name': 'Active',
#               'type': 'scatter',
#               'uid': '06a50b02-f580-48d2-bcc1-bd8c80e44d7d',
#               'x': array([datetime.datetime(2024, 12, 31, 23, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x',
#               'y': array([93460.421875]),
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '8805a619-dffd-45a0-8cf7-28af1a5b6d96',
#               'x': array([datetime.datetime(2024, 10, 20, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 1, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 2, 0, tzinfo=datetime.timezone.utc),
#                           ...,
#                           datetime.datetime(2024, 12, 31, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 22, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 23, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x2',
#               'y': array([68229.203125 , 68150.8359375, 68161.03125  , ..., 93746.2421875,
#                           93254.0625   , 93460.421875 ]),
#               'yaxis': 'y2'},
#              {'customdata': array([[0.00000000e+00, 1.41318694e-03, 9.99000999e-02],
#                                    [2.00000000e+00, 2.74379660e-03, 1.92024177e-01],
#                                    [4.00000000e+00, 2.58259401e-03, 2.35873718e-01],
#                                    [6.00000000e+00, 2.50554332e-03, 2.37844454e-01],
#                                    [8.00000000e+00, 2.43562505e-03, 2.41021463e-01],
#                                    [1.00000000e+01, 2.31258608e-03, 2.33245120e-01],
#                                    [1.20000000e+01, 2.23108537e-03, 2.20232842e-01],
#                                    [1.40000000e+01, 2.34856534e-03, 2.27814838e-01],
#                                    [1.60000000e+01, 2.42428918e-03, 2.36105387e-01],
#                                    [1.80000000e+01, 2.39703988e-03, 2.29882890e-01],
#                                    [2.00000000e+01, 2.35957204e-03, 2.25482142e-01]]),
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '5',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-up'},
#               'mode': 'markers',
#               'name': 'Buy',
#               'type': 'scatter',
#               'uid': 'fdf552b1-ae05-4c84-9c09-221f903eb9f5',
#               'x': array([datetime.datetime(2024, 10, 31, 15, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 5, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 15, 20, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 27, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 4, 20, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 6, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 11, 13, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 20, 15, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 24, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 26, 8, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 14, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x2',
#               'y': array([ 70691.35510937,  69984.84375   ,  91332.09375   ,  94927.296875  ,
#                            98956.71875   , 100859.        ,  98711.078125  ,  97001.703125  ,
#                            97391.59375   ,  95902.82264062,  95560.609375  ]),
#               'yaxis': 'y2'},
#              {'customdata': array([[1.00000000e+00, 2.82355033e-03, 1.92408609e-01],
#                                    [3.00000000e+00, 2.66420222e-03, 2.36345938e-01],
#                                    [5.00000000e+00, 2.50114884e-03, 2.38320619e-01],
#                                    [7.00000000e+00, 2.50992901e-03, 2.41503988e-01],
#                                    [9.00000000e+00, 2.36146955e-03, 2.33712077e-01],
#                                    [1.10000000e+01, 2.26380028e-03, 2.20673748e-01],
#                                    [1.30000000e+01, 2.19843581e-03, 2.28270924e-01],
#                                    [1.50000000e+01, 2.49839492e-03, 2.36578070e-01],
#                                    [1.70000000e+01, 2.35033150e-03, 2.30343116e-01],
#                                    [1.90000000e+01, 2.44365493e-03, 2.25933557e-01]]),
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '6',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-down'},
#               'mode': 'markers',
#               'name': 'Sell',
#               'type': 'scatter',
#               'uid': '9a0a929c-be13-4825-9d24-1eb59311e40c',
#               'x': array([datetime.datetime(2024, 11, 3, 2, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 13, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 25, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 27, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 5, 19, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 9, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 18, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 22, 19, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 24, 15, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 30, 13, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x2',
#               'y': array([ 68144.2109375 ,  88711.7109375 ,  95284.4609375 ,  96219.44985938,
#                            98968.9140625 ,  97479.3359375 , 103833.3359375 ,  94692.0234375 ,
#                            98004.522375  ,  92457.2265625 ]),
#               'yaxis': 'y2'},
#              {'customdata': array([[2.00000000e+00, 2.00000000e+00, 2.47594154e+01, 2.65317026e-01],
#                                    [4.00000000e+00, 4.00000000e+00, 4.71406077e+00, 4.12314059e-02],
#                                    [5.00000000e+00, 5.00000000e+00, 2.08577496e-01, 1.75214618e-03],
#                                    [6.00000000e+00, 6.00000000e+00, 1.38310547e+00, 1.15984156e-02],
#                                    [1.20000000e+01, 1.20000000e+01, 5.41324489e+00, 4.98395265e-02],
#                                    [1.30000000e+01, 1.30000000e+01, 7.28140295e+00, 6.38600091e-02],
#                                    [1.60000000e+01, 1.60000000e+01, 4.91160574e-01, 4.28715141e-03],
#                                    [1.70000000e+01, 1.70000000e+01, 2.23973030e+00, 1.94663710e-02]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '7',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'opacity': array([0.9       , 0.77246843, 0.75      , 0.75560371, 0.77736748, 0.78534682,
#                                            0.75144272, 0.76008152]),
#                          'size': array([14.        ,  8.04852672,  7.        ,  7.26150633,  8.27714915,
#                                          8.6495181 ,  7.06732701,  7.47047078]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Profit',
#               'type': 'scatter',
#               'uid': '30968621-2fae-4e20-a489-2218788a5b3e',
#               'x': array([datetime.datetime(2024, 11, 13, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 25, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 27, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 27, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 18, 4, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 20, 15, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 24, 15, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 26, 8, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([0.26531703, 0.04123141, 0.00175215, 0.01159842, 0.04983953, 0.06386001,
#                           0.00428715, 0.01946637]),
#               'yaxis': 'y3'},
#              {'customdata': array([[ 0.00000000e+00,  0.00000000e+00, -3.79579149e+00, -3.79958728e-02],
#                                    [ 1.00000000e+00,  1.00000000e+00, -2.79077330e+00, -2.90378572e-02],
#                                    [ 3.00000000e+00,  3.00000000e+00, -3.72672096e+00, -3.15677219e-02],
#                                    [ 7.00000000e+00,  7.00000000e+00, -3.67643435e+00, -3.04766351e-02],
#                                    [ 8.00000000e+00,  8.00000000e+00, -2.19517546e-01, -1.87688439e-03],
#                                    [ 9.00000000e+00,  9.00000000e+00, -2.46516633e+00, -2.11168716e-02],
#                                    [ 1.00000000e+01,  1.00000000e+01, -4.05399136e+00, -3.54752912e-02],
#                                    [ 1.10000000e+01,  1.10000000e+01, -1.61466084e+00, -1.46485672e-02],
#                                    [ 1.40000000e+01,  1.40000000e+01, -3.12783402e+00, -2.57869020e-02],
#                                    [ 1.50000000e+01,  1.50000000e+01, -3.60863450e+00, -3.05374605e-02],
#                                    [ 1.80000000e+01,  1.80000000e+01, -4.44450747e+00, -3.78920664e-02],
#                                    [ 1.90000000e+01,  1.90000000e+01, -4.01750219e+00, -3.55991713e-02]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '8',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'opacity': array([0.77062702, 0.76552884, 0.76696864, 0.76634768, 0.75007099, 0.76102085,
#                                            0.76919251, 0.75733961, 0.76367866, 0.76638229, 0.77056795, 0.76926301]),
#                          'size': array([7.96259443, 7.72467916, 7.79186965, 7.76289156, 7.00331291, 7.5143063 ,
#                                         7.89565049, 7.34251508, 7.63833729, 7.76450702, 7.95983745, 7.89894062]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Loss',
#               'type': 'scatter',
#               'uid': '0124b122-aa89-4272-9d70-f96d18f75adb',
#               'x': array([datetime.datetime(2024, 11, 3, 2, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 5, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 11, 15, 20, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 4, 20, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 5, 19, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 6, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 9, 17, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 11, 13, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 22, 19, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 24, 14, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 30, 13, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 14, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([-0.03799587, -0.02903786, -0.03156772, -0.03047664, -0.00187688,
#                           -0.02111687, -0.03547529, -0.01464857, -0.0257869 , -0.03053746,
#                           -0.03789207, -0.03559917]),
#               'yaxis': 'y3'},
#              {'customdata': array([[20.        , 20.        , -2.50088332, -0.02297754]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '9',
#               'marker': {'color': '#FFAA00',
#                          'line': {'color': 'rgb(178,118,0)', 'width': 1},
#                          'opacity': array([0.76207979]),
#                          'size': array([7.56372376]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Open',
#               'type': 'scatter',
#               'uid': '2f2c28d7-d9d8-47fa-b97c-27bfe348a023',
#               'x': array([datetime.datetime(2024, 12, 31, 23, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x3',
#               'y': array([-0.02297754]),
#               'yaxis': 'y3'},
#              {'legendgroup': '10',
#               'line': {'color': '#7f7f7f'},
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '45e55f10-369f-4741-8c56-bd30b1c01955',
#               'x': array([datetime.datetime(2024, 10, 20, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 1, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 2, 0, tzinfo=datetime.timezone.utc),
#                           ...,
#                           datetime.datetime(2024, 12, 31, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 22, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 23, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x4',
#               'y': array([1.        , 0.99885141, 0.99900084, ..., 1.37398999, 1.36677637,
#                           1.36980087]),
#               'yaxis': 'y4'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '11',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'e6349953-f328-4c7d-8b95-feab89018ea4',
#               'x': array([datetime.datetime(2024, 10, 20, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 1, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 2, 0, tzinfo=datetime.timezone.utc),
#                           ...,
#                           datetime.datetime(2024, 12, 31, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 22, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 23, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x4',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y4'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(0, 128, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '11',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '944e32a8-822e-4a3f-b2a7-0a0a89d49f6c',
#               'x': array([datetime.datetime(2024, 10, 20, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 1, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 2, 0, tzinfo=datetime.timezone.utc),
#                           ...,
#                           datetime.datetime(2024, 12, 31, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 22, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 23, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x4',
#               'y': array([1.        , 1.        , 1.        , ..., 1.0677382 , 1.06213244,
#                           1.0644828 ]),
#               'yaxis': 'y4'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '11',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '66b093e2-3dd7-4aca-a17b-eb86ad699732',
#               'x': array([datetime.datetime(2024, 10, 20, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 1, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 2, 0, tzinfo=datetime.timezone.utc),
#                           ...,
#                           datetime.datetime(2024, 12, 31, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 22, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 23, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x4',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y4'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '11',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '7051a05e-3167-4ebe-b244-7c468b6dedeb',
#               'x': array([datetime.datetime(2024, 10, 20, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 1, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 2, 0, tzinfo=datetime.timezone.utc),
#                           ...,
#                           datetime.datetime(2024, 12, 31, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 22, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 23, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x4',
#               'y': array([1., 1., 1., ..., 1., 1., 1.]),
#               'yaxis': 'y4'},
#              {'legendgroup': '12',
#               'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '8f0fca4d-967d-4770-90c6-3b27aa4f63b8',
#               'x': array([datetime.datetime(2024, 10, 20, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 1, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 2, 0, tzinfo=datetime.timezone.utc),
#                           ...,
#                           datetime.datetime(2024, 12, 31, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 22, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 23, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x4',
#               'y': array([1.        , 1.        , 1.        , ..., 1.0677382 , 1.06213244,
#                           1.0644828 ]),
#               'yaxis': 'y4'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '11',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'bd1983fd-e2bf-4a86-b2a6-858f17280e94',
#               'x': array([datetime.datetime(2024, 10, 20, 0, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 1, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 10, 20, 2, 0, tzinfo=datetime.timezone.utc),
#                           ...,
#                           datetime.datetime(2024, 12, 31, 21, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 22, 0, tzinfo=datetime.timezone.utc),
#                           datetime.datetime(2024, 12, 31, 23, 0, tzinfo=datetime.timezone.utc)],
#                          dtype=object),
#               'xaxis': 'x4',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y4'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trades',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Orders',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.742,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trade PnL',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.484,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Cumulative Returns',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.226,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 1250,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.032,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-11-05 14:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-11-13 21:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 69984.84375,
#                            'y1': 88711.7109375,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-11-15 20:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-11-25 17:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 91332.09375,
#                            'y1': 95284.4609375,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-11-25 17:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-11-27 14:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 95284.4609375,
#                            'y1': 94927.296875,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-11-27 14:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-11-27 17:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 94927.296875,
#                            'y1': 96219.449859375,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-11 13:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-18 04:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 98711.078125,
#                            'y1': 103833.3359375,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-18 04:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-20 15:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 103833.3359375,
#                            'y1': 97001.703125,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-24 14:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-24 15:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 97391.59375,
#                            'y1': 98004.522375,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-24 15:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-26 08:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 98004.522375,
#                            'y1': 95902.82264062499,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-10-31 15:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-11-03 02:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 70691.355109375,
#                            'y1': 68144.2109375,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-11-03 02:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-11-05 14:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 68144.2109375,
#                            'y1': 69984.84375,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-11-13 21:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-11-15 20:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 88711.7109375,
#                            'y1': 91332.09375,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-11-27 17:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-04 20:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 96219.449859375,
#                            'y1': 98956.71875,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-04 20:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-05 19:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 98956.71875,
#                            'y1': 98968.9140625,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-05 19:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-06 17:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 98968.9140625,
#                            'y1': 100859.0,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-06 17:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-09 17:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 100859.0,
#                            'y1': 97479.3359375,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-09 17:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-11 13:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 97479.3359375,
#                            'y1': 98711.078125,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-20 15:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-22 19:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 97001.703125,
#                            'y1': 94692.0234375,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-22 19:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-24 14:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 94692.0234375,
#                            'y1': 97391.59375,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-26 08:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-30 13:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 95902.82264062499,
#                            'y1': 92457.2265625,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-30 13:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-31 14:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 92457.2265625,
#                            'y1': 95560.609375,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-31 14:00:00+0000', tz='UTC'),
#                            'x1': Timestamp('2024-12-31 23:00:00+0000', tz='UTC'),
#                            'xref': 'x',
#                            'y0': 95560.609375,
#                            'y1': 93460.421875,
#                            'yref': 'y'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y3'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y4'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 750,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'matches': 'x4', 'showticklabels': False},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'matches': 'x4', 'showticklabels': False},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'matches': 'x4', 'showticklabels': False},
#                'xaxis4': {'anchor': 'y4', 'domain': [0.0, 1.0], 'title': {'text': 'Index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.774, 1.0], 'title': {'text': 'Price'}},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.516, 0.742], 'title': {'text': 'Price'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.258, 0.484], 'tickformat': '.2%', 'title': {'text': 'Trade PnL'}},
#                'yaxis4': {'anchor': 'x4', 'domain': [0.0, 0.226], 'title': {'text': 'Cumulative returns'}}}
# })
