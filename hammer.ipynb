# %%
#Import library
import numpy as np
import pandas as pd
import vectorbt as bt
import yfinance as yf
import pandas_ta as ta

# %%
#Get Data
btc = yf.download('BTC-USD', start='2024-12-04', end='2024-12-11', interval='15m')
btc.columns = ['Close', 'High', 'Low', 'Open', 'Volume']
btc = btc.asfreq('15min')
btc.tail()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                             Close          High           Low          Open  \
# Datetime
# 2024-12-10 22:45:00  96944.890625  96944.890625  96798.007812  96798.007812
# 2024-12-10 23:00:00  97061.710938  97164.054688  96972.546875  96972.546875
# 2024-12-10 23:15:00  97045.945312  97087.039062  96899.671875  96899.671875
# 2024-12-10 23:30:00  96826.585938  97136.046875  96826.585938  97045.546875
# 2024-12-10 23:45:00  96681.914062  96732.703125  96614.171875  96732.703125
#
#                         Volume
# Datetime
# 2024-12-10 22:45:00          0
# 2024-12-10 23:00:00          0
# 2024-12-10 23:15:00          0
# 2024-12-10 23:30:00          0
# 2024-12-10 23:45:00  142614528

# %%
# Initial parameters
initial_capital = 100000
risk_per_trade = 0.02  # 2%sl_trail=True
stop_loss = 0.18  # 18%
take_profit = 0.40  # 40%

# %%
#Technical Indicators
btc['rsi']= ta.rsi(btc['Close'], length=14)
btc['ema_short'] = ta.ema(btc['Close'], length=20)
btc['ema_long'] = ta.ema(btc['Close'], length=50)
btc['vwap'] = ta.vwap(btc['High'], btc['Low'], btc['Close'], btc['Volume'])
bb = ta.bbands(btc['Close'], length=20, std=2)
adx_results = ta.adx(btc['High'], btc['Low'], btc['Close'], length=5)

# Assign to DataFrame
btc['adx'] = adx_results['ADX_5']  # ADX values
btc['a'] = adx_results['DMP_5']    # Positive Directional Movement
btc['b'] = adx_results['DMN_5']    # Negative Directional Movement

btc['bbl'] = bb['BBL_20_2.0']
btc['bbm'] = bb['BBM_20_2.0']
btc['bbu'] = bb['BBU_20_2.0']

# %%
#Entry and Exit 
btc['long_entry'] = ((((btc['Close'] - btc['Open']) < 0.38*(btc['High'] - btc['Low'])) &
                      (btc['Close'] > btc['Open']) &
                      ((btc['High'] - btc['Close']) < 0.7*(btc['Close'] - btc['Open'])))
                      ).astype(int)
btc['long_exit'] = (btc['rsi'] > 70).astype(int)

btc['short_entry'] = ((((btc['Open'] - btc['Close']) < 0.38*(btc['High'] - btc['Low'])) &
                      (btc['Close'] < btc['Open']) &
                      ((btc['Close'] - btc['Low']) < 0.7*(btc['Open'] - btc['Close'])))
                      ).astype(int)
btc['short_exit'] = (btc['rsi']<30).astype(int)

# %%
#Portfolio Construction
pf = bt.Portfolio.from_signals(btc['Close'], entries=btc['long_entry'], short_entries=btc['short_entry'],fees=0.001, slippage=0.001, sl_stop=0.04, sl_trail=True, upon_stop_exit='reverse', )

# %%
#Returns
returns = pf.total_return()
print(returns)
# Out:
# -0.027311303575621223

# %%
#Stats
pf.stats()
# Out:
# Start                         2024-12-04 00:00:00
# End                           2024-12-10 23:45:00
# Period                            7 days 00:00:00
# Start Value                                 100.0
# End Value                                97.26887
# Total Return [%]                         -2.73113
# Benchmark Return [%]                     0.669528
# Max Gross Exposure [%]                      100.0
# Total Fees Paid                          5.969635
# Max Drawdown [%]                        12.328658
# Max Drawdown Duration             5 days 01:30:00
# Total Trades                                   31
# Total Closed Trades                            30
# Total Open Trades                               1
# Open Trade PnL                           -0.11119
# Win Rate [%]                            43.333333
# Best Trade [%]                           3.407389
# Worst Trade [%]                         -3.944679
# Avg Winning Trade [%]                    1.224855
# Avg Losing Trade [%]                    -1.071569
# Avg Winning Trade Duration        0 days 06:06:55
# Avg Losing Trade Duration         0 days 04:34:24
# Profit Factor                             0.85563
# Expectancy                              -0.087331
# Sharpe Ratio                            -1.888529
# Calmar Ratio                            -6.196895
# Omega Ratio                              0.969203
# Sortino Ratio                           -2.675233
# dtype: object

# %%
#Plots
pf.plot(
    subplots=['trades', 'orders', 'trade_pnl', 'cum_returns']
    )
# Out:
# FigureWidget({
#     'data': [{'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': '6ab69f57-3ed6-4363-879c-866e4024fa0f',
#               'x': array([datetime.datetime(2024, 12, 4, 0, 0),
#                           datetime.datetime(2024, 12, 4, 0, 15),
#                           datetime.datetime(2024, 12, 4, 0, 30), ...,
#                           datetime.datetime(2024, 12, 10, 23, 15),
#                           datetime.datetime(2024, 12, 10, 23, 30),
#                           datetime.datetime(2024, 12, 10, 23, 45)], dtype=object),
#               'xaxis': 'x',
#               'y': array([96038.90625  , 95989.3671875, 95739.       , ..., 97045.9453125,
#                           96826.5859375, 96681.9140625]),
#               'yaxis': 'y'},
#              {'customdata': array([[0, 0, 0.0010333300099976842, 0.09990009990009993, 'Short'],
#                                    [1, 1, 0.0010492610770620732, 0.10056373572381612, 'Long'],
#                                    [2, 2, 0.0010471646513336775, 0.10342513269941488, 'Short'],
#                                    [3, 3, 0.0010398023625349058, 0.10295731781990632, 'Long'],
#                                    [4, 4, 0.001037724835337034, 0.1020198683000348, 'Short'],
#                                    [5, 5, 0.0009712046824685132, 0.09854321889333387, 'Long'],
#                                    [6, 6, 0.000969264213572472, 0.09982156415343041, 'Short'],
#                                    [7, 7, 0.0009849433687946676, 0.10052193860525571, 'Long'],
#                                    [8, 8, 0.0009829754499758971, 0.09974894665463714, 'Short'],
#                                    [9, 9, 0.0010544353819411662, 0.10314438627011632, 'Long'],
#                                    [10, 10, 0.0010523286179412842, 0.10313322640195174, 'Short'],
#                                    [11, 11, 0.0009744071268299379, 0.0990690155049186, 'Long'],
#                                    [12, 12, 0.0009724602594436643, 0.09753199390645809, 'Short'],
#                                    [13, 13, 0.000981069953393804, 0.09786397770502789, 'Long'],
#                                    [14, 14, 0.0009791097736667434, 0.09740337483240688, 'Short'],
#                                    [15, 15, 0.0009599066111114359, 0.09634239240134834, 'Long'],
#                                    [16, 16, 0.00095798871578454, 0.09597998356631085, 'Short'],
#                                    [17, 17, 0.0009595001013845881, 0.09595967635985217, 'Long'],
#                                    [18, 18, 0.0009575830182649387, 0.09571667507175717, 'Short'],
#                                    [19, 19, 0.0009622795319786774, 0.09585496950894735, 'Long'],
#                                    [20, 20, 0.0009603568955511477, 0.09601749240504356, 'Short'],
#                                    [21, 21, 0.0009735556649296451, 0.09657622643638263, 'Long'],
#                                    [22, 22, 0.0009716104987659497, 0.09622668245312266, 'Short'],
#                                    [23, 23, 0.0009582583352395332, 0.09546545444678725, 'Long'],
#                                    [24, 24, 0.0009563437331711229, 0.09356278883144604, 'Short'],
#                                    [25, 25, 0.0009800717418191327, 0.0946146526547073, 'Long'],
#                                    [26, 26, 0.0009781135565207928, 0.09497787804482381, 'Short'],
#                                    [27, 27, 0.0009620407035091077, 0.0940969542363233, 'Long'],
#                                    [28, 28, 0.0009601185442613374, 0.09327663573566985, 'Short'],
#                                    [29, 29, 0.001008373423169396, 0.0954677167256766, 'Long'],
#                                    [30, 30, 0.0010063586910551714, 0.09728277706354196, 'Short']],
#                                   dtype=object),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'br>Direction: %{customdata[4]}'),
#               'legendgroup': '1',
#               'marker': {'color': '#4285F4',
#                          'line': {'color': 'rgb(11,84,205)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'square'},
#               'mode': 'markers',
#               'name': 'Entry',
#               'type': 'scatter',
#               'uid': '871b7d82-0916-4576-8db7-e1e39b8a8b84',
#               'x': array([datetime.datetime(2024, 12, 4, 8, 45),
#                           datetime.datetime(2024, 12, 4, 13, 45),
#                           datetime.datetime(2024, 12, 4, 21, 0),
#                           datetime.datetime(2024, 12, 5, 0, 15),
#                           datetime.datetime(2024, 12, 5, 0, 45),
#                           datetime.datetime(2024, 12, 5, 2, 45),
#                           datetime.datetime(2024, 12, 5, 3, 45),
#                           datetime.datetime(2024, 12, 5, 6, 30),
#                           datetime.datetime(2024, 12, 5, 16, 15),
#                           datetime.datetime(2024, 12, 6, 3, 45),
#                           datetime.datetime(2024, 12, 6, 6, 30),
#                           datetime.datetime(2024, 12, 6, 18, 0),
#                           datetime.datetime(2024, 12, 7, 1, 0),
#                           datetime.datetime(2024, 12, 7, 5, 0),
#                           datetime.datetime(2024, 12, 7, 8, 45),
#                           datetime.datetime(2024, 12, 7, 19, 30),
#                           datetime.datetime(2024, 12, 7, 20, 15),
#                           datetime.datetime(2024, 12, 8, 0, 15),
#                           datetime.datetime(2024, 12, 8, 1, 0),
#                           datetime.datetime(2024, 12, 8, 11, 15),
#                           datetime.datetime(2024, 12, 8, 14, 30),
#                           datetime.datetime(2024, 12, 9, 3, 45),
#                           datetime.datetime(2024, 12, 9, 6, 45),
#                           datetime.datetime(2024, 12, 9, 8, 30),
#                           datetime.datetime(2024, 12, 9, 18, 45),
#                           datetime.datetime(2024, 12, 9, 21, 0),
#                           datetime.datetime(2024, 12, 10, 6, 30),
#                           datetime.datetime(2024, 12, 10, 11, 15),
#                           datetime.datetime(2024, 12, 10, 12, 30),
#                           datetime.datetime(2024, 12, 10, 18, 0),
#                           datetime.datetime(2024, 12, 10, 22, 0)], dtype=object),
#               'xaxis': 'x',
#               'y': array([ 96677.82696094,  95842.4341875 ,  98766.82961719,  99016.23763281,
#                            98311.09830469, 101464.93388281, 102986.94902344, 102058.59726562,
#                           101476.53907031,  97819.54213281,  98004.772125  , 101671.0703125 ,
#                           100294.06647656,  99752.29326562,  99481.56728906, 100366.42240625,
#                           100189.05440625, 100010.07422656,  99956.52935156,  99612.39569531,
#                            99981.05167969,  99199.49101562,  99038.33128125,  99623.92283594,
#                            97833.84946875,  96538.49674219,  97103.11999219,  97809.74328125,
#                            97151.16564844,  94674.96319531,  96668.09451562]),
#               'yaxis': 'y'},
#              {'customdata': array([[0, 0, 0.0010333300099976842, 0.09903686347716094, 0.6642994595509211,
#                                     0.006649637590104718, 'Short', '0 days 05:00:00'],
#                                    [1, 1, 0.0010492610770620732, 0.1036321900221364, 2.864258372563367,
#                                     0.028482020401761215, 'Long', '0 days 07:15:00'],
#                                    [5, 5, 0.0009712046824685132, 0.10002140712470858, 1.2796236053449355,
#                                     0.012985404979817905, 'Long', '0 days 01:00:00'],
#                                    [6, 6, 0.000969264213572472, 0.09892174601696857, 0.7010748262843559,
#                                     0.0070232803125261705, 'Short', '0 days 02:45:00'],
#                                    [8, 8, 0.0009829754499758971, 0.09615420844443215, 3.398835055100482,
#                                     0.034073894202295084, 'Short', '0 days 11:30:00'],
#                                    [12, 12, 0.0009724602594436643, 0.0970051409891863, 0.3323157823722722,
#                                     0.0034072489350621994, 'Short', '0 days 04:00:00'],
#                                    [18, 18, 0.0009575830182649387, 0.09538713852650603,
#                                     0.1384327316401628, 0.0014462760175944487, 'Short', '0 days 10:15:00'],
#                                    [19, 19, 0.0009622795319786774, 0.09620971961706565,
#                                     0.16268541897950722, 0.0016972038050077317, 'Long', '0 days 03:15:00'],
#                                    [20, 20, 0.0009603568955511477, 0.09526691523200327,
#                                     0.5592927653869233, 0.005824904935317236, 'Short', '0 days 13:15:00'],
#                                    [24, 24, 0.0009563437331711229, 0.09232398636914303,
#                                     1.0529156870935994, 0.011253573137825483, 'Short', '0 days 02:15:00'],
#                                    [25, 25, 0.0009800717418191327, 0.09516802394681544,
#                                     0.36358861549754956, 0.0038428362340917534, 'Long', '0 days 09:30:00'],
#                                    [28, 28, 0.0009601185442613374, 0.09089918784106273, 2.193272071013998,
#                                     0.02351362754151381, 'Short', '0 days 05:30:00'],
#                                    [29, 29, 0.001008373423169396, 0.09747753737798348, 1.8168753981859875,
#                                     0.0190313067128901, 'Long', '0 days 04:00:00']], dtype=object),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... '<br>Duration: %{customdata[7]}'),
#               'legendgroup': '2',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'square'},
#               'mode': 'markers',
#               'name': 'Exit - Profit',
#               'type': 'scatter',
#               'uid': '06d683ef-5312-4d73-bf5f-b477007d59d6',
#               'x': array([datetime.datetime(2024, 12, 4, 13, 45),
#                           datetime.datetime(2024, 12, 4, 21, 0),
#                           datetime.datetime(2024, 12, 5, 3, 45),
#                           datetime.datetime(2024, 12, 5, 6, 30),
#                           datetime.datetime(2024, 12, 6, 3, 45),
#                           datetime.datetime(2024, 12, 7, 5, 0),
#                           datetime.datetime(2024, 12, 8, 11, 15),
#                           datetime.datetime(2024, 12, 8, 14, 30),
#                           datetime.datetime(2024, 12, 9, 3, 45),
#                           datetime.datetime(2024, 12, 9, 21, 0),
#                           datetime.datetime(2024, 12, 10, 6, 30),
#                           datetime.datetime(2024, 12, 10, 18, 0),
#                           datetime.datetime(2024, 12, 10, 22, 0)], dtype=object),
#               'xaxis': 'x',
#               'y': array([ 95842.4341875 ,  98766.82961719, 102986.94902344, 102058.59726562,
#                            97819.54213281,  99752.29326562,  99612.39569531,  99981.05167969,
#                            99199.49101562,  96538.49674219,  97103.11999219,  94674.96319531,
#                            96668.09451562]),
#               'yaxis': 'y'},
#              {'customdata': array([[2, 2, 0.0010471646513336775, 0.10368630395712679, -0.4682826943783261,
#                                     -0.00452774564707883, 'Short', '0 days 03:15:00'],
#                                    [3, 3, 0.0010398023625349058, 0.10222411228061544, -0.9383869694011632,
#                                     -0.009114329989078653, 'Long', '0 days 00:30:00'],
#                                    [4, 4, 0.001037724835337034, 0.10529268180601212, -3.4801260560958776,
#                                     -0.03411223827363724, 'Short', '0 days 02:00:00'],
#                                    [7, 7, 0.0009849433687946676, 0.0999486442455373, -0.7737649425764154,
#                                     -0.007697473340768859, 'Long', '0 days 09:45:00'],
#                                    [9, 9, 0.0010544353819411662, 0.10333969932768136,
#                                     -0.011171028038593545, -0.00010830476037094283, 'Long',
#                                     '0 days 02:45:00'],
#                                    [10, 10, 0.0010523286179412842, 0.1069913769065544, -4.068275107921016,
#                                     -0.039446793723540735, 'Short', '0 days 11:30:00'],
#                                    [11, 11, 0.0009744071268299379, 0.09772725315351805,
#                                     -1.538558620068107, -0.015530169672389432, 'Long', '0 days 07:00:00'],
#                                    [13, 13, 0.000981069953393804, 0.09759837658382314,
#                                     -0.4610634754974979, -0.004711268500521943, 'Long', '0 days 03:45:00'],
#                                    [14, 14, 0.0009791097736667434, 0.09826974512590991,
#                                     -1.062043413475609, -0.010903558683700335, 'Short', '0 days 10:45:00'],
#                                    [15, 15, 0.0009599066111114359, 0.09617213568556271,
#                                     -0.36277124388652104, -0.003765437361937374, 'Long',
#                                     '0 days 00:45:00'],
#                                    [16, 16, 0.00095798871578454, 0.09580852257380643,
#                                     -0.020327513650389817, -0.000211789092840862, 'Short',
#                                     '0 days 04:00:00'],
#                                    [17, 17, 0.0009595001013845881, 0.09590830004687577,
#                                     -0.24324428939785192, -0.0025348594183002447, 'Long',
#                                     '0 days 00:45:00'],
#                                    [21, 21, 0.0009735556649296451, 0.0964193284640398,
#                                     -0.34989352725973977, -0.0036229778297474104, 'Long',
#                                     '0 days 03:00:00'],
#                                    [22, 22, 0.0009716104987659497, 0.09679564935563564,
#                                     -0.7619892343318027, -0.007918689649339306, 'Short',
#                                     '0 days 01:45:00'],
#                                    [23, 23, 0.0009582583352395332, 0.09375010172199948,
#                                     -1.9045682809664835, -0.019950340068070362, 'Long', '0 days 10:15:00'],
#                                    [26, 26, 0.0009781135565207928, 0.09566903586319325,
#                                     -0.8818047322933522, -0.009284317047778155, 'Short',
#                                     '0 days 04:45:00'],
#                                    [27, 27, 0.0009620407035091077, 0.09346337574715266,
#                                     -0.8211388191697674, -0.00872651857686436, 'Long', '0 days 01:15:00']],
#                                   dtype=object),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... '<br>Duration: %{customdata[7]}'),
#               'legendgroup': '3',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'square'},
#               'mode': 'markers',
#               'name': 'Exit - Loss',
#               'type': 'scatter',
#               'uid': '98c3953a-8749-436f-b6ba-df6fd3cea96a',
#               'x': array([datetime.datetime(2024, 12, 5, 0, 15),
#                           datetime.datetime(2024, 12, 5, 0, 45),
#                           datetime.datetime(2024, 12, 5, 2, 45),
#                           datetime.datetime(2024, 12, 5, 16, 15),
#                           datetime.datetime(2024, 12, 6, 6, 30),
#                           datetime.datetime(2024, 12, 6, 18, 0),
#                           datetime.datetime(2024, 12, 7, 1, 0),
#                           datetime.datetime(2024, 12, 7, 8, 45),
#                           datetime.datetime(2024, 12, 7, 19, 30),
#                           datetime.datetime(2024, 12, 7, 20, 15),
#                           datetime.datetime(2024, 12, 8, 0, 15),
#                           datetime.datetime(2024, 12, 8, 1, 0),
#                           datetime.datetime(2024, 12, 9, 6, 45),
#                           datetime.datetime(2024, 12, 9, 8, 30),
#                           datetime.datetime(2024, 12, 9, 18, 45),
#                           datetime.datetime(2024, 12, 10, 11, 15),
#                           datetime.datetime(2024, 12, 10, 12, 30)], dtype=object),
#               'xaxis': 'x',
#               'y': array([ 99016.23763281,  98311.09830469, 101464.93388281, 101476.53907031,
#                            98004.772125  , 101671.0703125 , 100294.06647656,  99481.56728906,
#                           100366.42240625, 100189.05440625, 100010.07422656,  99956.52935156,
#                            99038.33128125,  99623.92283594,  97833.84946875,  97809.74328125,
#                            97151.16564844]),
#               'yaxis': 'y'},
#              {'customdata': array([[30, 30, 0.0010063586910551714, 0.0, -0.11119019816764966,
#                                     -0.001142958718119486, 'Short', '0 days 02:00:00']], dtype=object),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... '<br>Duration: %{customdata[7]}'),
#               'legendgroup': '4',
#               'marker': {'color': '#FFAA00',
#                          'line': {'color': 'rgb(178,118,0)', 'width': 1},
#                          'size': 7,
#                          'symbol': 'square'},
#               'mode': 'markers',
#               'name': 'Active',
#               'type': 'scatter',
#               'uid': '92b7fcae-b62b-4bb2-9453-eaa4c53fc719',
#               'x': array([datetime.datetime(2024, 12, 10, 23, 45)], dtype=object),
#               'xaxis': 'x',
#               'y': array([96681.9140625]),
#               'yaxis': 'y'},
#              {'legendgroup': '0',
#               'line': {'color': '#1f77b4'},
#               'name': 'Close',
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '331aa0af-7863-42c0-9ff0-f6bfb0f6e995',
#               'x': array([datetime.datetime(2024, 12, 4, 0, 0),
#                           datetime.datetime(2024, 12, 4, 0, 15),
#                           datetime.datetime(2024, 12, 4, 0, 30), ...,
#                           datetime.datetime(2024, 12, 10, 23, 15),
#                           datetime.datetime(2024, 12, 10, 23, 30),
#                           datetime.datetime(2024, 12, 10, 23, 45)], dtype=object),
#               'xaxis': 'x2',
#               'y': array([96038.90625  , 95989.3671875, 95739.       , ..., 97045.9453125,
#                           96826.5859375, 96681.9140625]),
#               'yaxis': 'y2'},
#              {'customdata': array([[1.00000000e+00, 2.08259109e-03, 1.99600599e-01],
#                                    [3.00000000e+00, 2.08696701e-03, 2.06643622e-01],
#                                    [5.00000000e+00, 2.00892952e-03, 2.03835901e-01],
#                                    [7.00000000e+00, 1.95420758e-03, 1.99443685e-01],
#                                    [9.00000000e+00, 2.03741083e-03, 1.99298595e-01],
#                                    [1.10000000e+01, 2.02673574e-03, 2.06060392e-01],
#                                    [1.30000000e+01, 1.95353021e-03, 1.94869119e-01],
#                                    [1.50000000e+01, 1.93901638e-03, 1.94612138e-01],
#                                    [1.70000000e+01, 1.91748882e-03, 1.91768199e-01],
#                                    [1.90000000e+01, 1.91986255e-03, 1.91242108e-01],
#                                    [2.10000000e+01, 1.93391256e-03, 1.91843142e-01],
#                                    [2.30000000e+01, 1.92986883e-03, 1.92261104e-01],
#                                    [2.50000000e+01, 1.93641547e-03, 1.86938639e-01],
#                                    [2.70000000e+01, 1.94015426e-03, 1.89765990e-01],
#                                    [2.90000000e+01, 1.96849197e-03, 1.86366905e-01]]),
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '5',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-up'},
#               'mode': 'markers',
#               'name': 'Buy',
#               'type': 'scatter',
#               'uid': '32679d22-70d5-44b5-850e-e23e871d5797',
#               'x': array([datetime.datetime(2024, 12, 4, 13, 45),
#                           datetime.datetime(2024, 12, 5, 0, 15),
#                           datetime.datetime(2024, 12, 5, 2, 45),
#                           datetime.datetime(2024, 12, 5, 6, 30),
#                           datetime.datetime(2024, 12, 6, 3, 45),
#                           datetime.datetime(2024, 12, 6, 18, 0),
#                           datetime.datetime(2024, 12, 7, 5, 0),
#                           datetime.datetime(2024, 12, 7, 19, 30),
#                           datetime.datetime(2024, 12, 8, 0, 15),
#                           datetime.datetime(2024, 12, 8, 11, 15),
#                           datetime.datetime(2024, 12, 9, 3, 45),
#                           datetime.datetime(2024, 12, 9, 8, 30),
#                           datetime.datetime(2024, 12, 9, 21, 0),
#                           datetime.datetime(2024, 12, 10, 11, 15),
#                           datetime.datetime(2024, 12, 10, 18, 0)], dtype=object),
#               'xaxis': 'x2',
#               'y': array([ 95842.4341875 ,  99016.23763281, 101464.93388281, 102058.59726562,
#                            97819.54213281, 101671.0703125 ,  99752.29326562, 100366.42240625,
#                           100010.07422656,  99612.39569531,  99199.49101562,  99623.92283594,
#                            96538.49674219,  97809.74328125,  94674.96319531]),
#               'yaxis': 'y2'},
#              {'customdata': array([[0.00000000e+00, 1.03333001e-03, 9.99000999e-02],
#                                    [2.00000000e+00, 2.09642573e-03, 2.07057323e-01],
#                                    [4.00000000e+00, 2.07752720e-03, 2.04243981e-01],
#                                    [6.00000000e+00, 1.94046890e-03, 1.99842971e-01],
#                                    [8.00000000e+00, 1.96791882e-03, 1.99697591e-01],
#                                    [1.00000000e+01, 2.10676400e-03, 2.06472926e-01],
#                                    [1.20000000e+01, 1.94686739e-03, 1.95259247e-01],
#                                    [1.40000000e+01, 1.96017973e-03, 1.95001751e-01],
#                                    [1.60000000e+01, 1.91789533e-03, 1.92152119e-01],
#                                    [1.80000000e+01, 1.91708312e-03, 1.91624975e-01],
#                                    [2.00000000e+01, 1.92263643e-03, 1.92227212e-01],
#                                    [2.20000000e+01, 1.94516616e-03, 1.92646011e-01],
#                                    [2.40000000e+01, 1.91460207e-03, 1.87312891e-01],
#                                    [2.60000000e+01, 1.95818530e-03, 1.90145902e-01],
#                                    [2.80000000e+01, 1.92215925e-03, 1.86740011e-01],
#                                    [3.00000000e+01, 2.01473211e-03, 1.94760314e-01]]),
#               'hovertemplate': ('Order Id: %{customdata[0]}<br>' ... '<br>Fees: %{customdata[2]:.6f}'),
#               'legendgroup': '6',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'size': 8,
#                          'symbol': 'triangle-down'},
#               'mode': 'markers',
#               'name': 'Sell',
#               'type': 'scatter',
#               'uid': '26849b66-92a9-4bd7-83c2-98eecd35ab67',
#               'x': array([datetime.datetime(2024, 12, 4, 8, 45),
#                           datetime.datetime(2024, 12, 4, 21, 0),
#                           datetime.datetime(2024, 12, 5, 0, 45),
#                           datetime.datetime(2024, 12, 5, 3, 45),
#                           datetime.datetime(2024, 12, 5, 16, 15),
#                           datetime.datetime(2024, 12, 6, 6, 30),
#                           datetime.datetime(2024, 12, 7, 1, 0),
#                           datetime.datetime(2024, 12, 7, 8, 45),
#                           datetime.datetime(2024, 12, 7, 20, 15),
#                           datetime.datetime(2024, 12, 8, 1, 0),
#                           datetime.datetime(2024, 12, 8, 14, 30),
#                           datetime.datetime(2024, 12, 9, 6, 45),
#                           datetime.datetime(2024, 12, 9, 18, 45),
#                           datetime.datetime(2024, 12, 10, 6, 30),
#                           datetime.datetime(2024, 12, 10, 12, 30),
#                           datetime.datetime(2024, 12, 10, 22, 0)], dtype=object),
#               'xaxis': 'x2',
#               'y': array([ 96677.82696094,  98766.82961719,  98311.09830469, 102986.94902344,
#                           101476.53907031,  98004.772125  , 100294.06647656,  99481.56728906,
#                           100189.05440625,  99956.52935156,  99981.05167969,  99038.33128125,
#                            97833.84946875,  97103.11999219,  97151.16564844,  96668.09451562]),
#               'yaxis': 'y2'},
#              {'customdata': array([[0.00000000e+00, 0.00000000e+00, 6.64299460e-01, 6.64963759e-03],
#                                    [1.00000000e+00, 1.00000000e+00, 2.86425837e+00, 2.84820204e-02],
#                                    [5.00000000e+00, 5.00000000e+00, 1.27962361e+00, 1.29854050e-02],
#                                    [6.00000000e+00, 6.00000000e+00, 7.01074826e-01, 7.02328031e-03],
#                                    [8.00000000e+00, 8.00000000e+00, 3.39883506e+00, 3.40738942e-02],
#                                    [1.20000000e+01, 1.20000000e+01, 3.32315782e-01, 3.40724894e-03],
#                                    [1.80000000e+01, 1.80000000e+01, 1.38432732e-01, 1.44627602e-03],
#                                    [1.90000000e+01, 1.90000000e+01, 1.62685419e-01, 1.69720381e-03],
#                                    [2.00000000e+01, 2.00000000e+01, 5.59292765e-01, 5.82490494e-03],
#                                    [2.40000000e+01, 2.40000000e+01, 1.05291569e+00, 1.12535731e-02],
#                                    [2.50000000e+01, 2.50000000e+01, 3.63588615e-01, 3.84283623e-03],
#                                    [2.80000000e+01, 2.80000000e+01, 2.19327207e+00, 2.35136275e-02],
#                                    [2.90000000e+01, 2.90000000e+01, 1.81687540e+00, 1.90313067e-02]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '7',
#               'marker': {'color': '#37B13F',
#                          'line': {'color': 'rgb(38,123,44)', 'width': 1},
#                          'opacity': array([0.77494249, 0.85819067, 0.79910115, 0.77636721, 0.87951281, 0.76257907,
#                                            0.75510176, 0.75605857, 0.77179774, 0.79249757, 0.76423999, 0.83924589,
#                                            0.82215453]),
#                          'size': array([ 8.16398293, 12.04889778,  9.29138698,  8.23046996, 13.04393133,
#                                          7.58702329,  7.23808232,  7.28273311,  8.01722771,  8.98322001,
#                                          7.6645329 , 11.16480815, 10.36721153]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Profit',
#               'type': 'scatter',
#               'uid': '6f18d163-a120-4fd1-aa46-a54d6e8cb8b0',
#               'x': array([datetime.datetime(2024, 12, 4, 13, 45),
#                           datetime.datetime(2024, 12, 4, 21, 0),
#                           datetime.datetime(2024, 12, 5, 3, 45),
#                           datetime.datetime(2024, 12, 5, 6, 30),
#                           datetime.datetime(2024, 12, 6, 3, 45),
#                           datetime.datetime(2024, 12, 7, 5, 0),
#                           datetime.datetime(2024, 12, 8, 11, 15),
#                           datetime.datetime(2024, 12, 8, 14, 30),
#                           datetime.datetime(2024, 12, 9, 3, 45),
#                           datetime.datetime(2024, 12, 9, 21, 0),
#                           datetime.datetime(2024, 12, 10, 6, 30),
#                           datetime.datetime(2024, 12, 10, 18, 0),
#                           datetime.datetime(2024, 12, 10, 22, 0)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([0.00664964, 0.02848202, 0.0129854 , 0.00702328, 0.03407389, 0.00340725,
#                           0.00144628, 0.0016972 , 0.0058249 , 0.01125357, 0.00384284, 0.02351363,
#                           0.01903131]),
#               'yaxis': 'y3'},
#              {'customdata': array([[ 2.00000000e+00,  2.00000000e+00, -4.68282694e-01, -4.52774565e-03],
#                                    [ 3.00000000e+00,  3.00000000e+00, -9.38386969e-01, -9.11432999e-03],
#                                    [ 4.00000000e+00,  4.00000000e+00, -3.48012606e+00, -3.41122383e-02],
#                                    [ 7.00000000e+00,  7.00000000e+00, -7.73764943e-01, -7.69747334e-03],
#                                    [ 9.00000000e+00,  9.00000000e+00, -1.11710280e-02, -1.08304760e-04],
#                                    [ 1.00000000e+01,  1.00000000e+01, -4.06827511e+00, -3.94467937e-02],
#                                    [ 1.10000000e+01,  1.10000000e+01, -1.53855862e+00, -1.55301697e-02],
#                                    [ 1.30000000e+01,  1.30000000e+01, -4.61063475e-01, -4.71126850e-03],
#                                    [ 1.40000000e+01,  1.40000000e+01, -1.06204341e+00, -1.09035587e-02],
#                                    [ 1.50000000e+01,  1.50000000e+01, -3.62771244e-01, -3.76543736e-03],
#                                    [ 1.60000000e+01,  1.60000000e+01, -2.03275137e-02, -2.11789093e-04],
#                                    [ 1.70000000e+01,  1.70000000e+01, -2.43244289e-01, -2.53485942e-03],
#                                    [ 2.10000000e+01,  2.10000000e+01, -3.49893527e-01, -3.62297783e-03],
#                                    [ 2.20000000e+01,  2.20000000e+01, -7.61989234e-01, -7.91868965e-03],
#                                    [ 2.30000000e+01,  2.30000000e+01, -1.90456828e+00, -1.99503401e-02],
#                                    [ 2.60000000e+01,  2.60000000e+01, -8.81804732e-01, -9.28431705e-03],
#                                    [ 2.70000000e+01,  2.70000000e+01, -8.21138819e-01, -8.72651858e-03]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '8',
#               'marker': {'color': '#EA4335',
#                          'line': {'color': 'rgb(181,31,18)', 'width': 1},
#                          'opacity': array([0.76685159, 0.78434051, 0.87965902, 0.77893795, 0.75      , 0.9       ,
#                                            0.80880449, 0.76755137, 0.79116295, 0.76394486, 0.75039459, 0.7592526 ,
#                                            0.76340166, 0.77978146, 0.82565886, 0.78498868, 0.78286176]),
#                          'size': array([ 7.78640759,  8.60255715, 13.05075438,  8.35043774,  7.        ,
#                                         14.        ,  9.74420948,  7.81906415,  8.92093747,  7.65076033,
#                                          7.01841429,  7.43178788,  7.62541069,  8.38980158, 10.53074688,
#                                          8.63280512,  8.53354891]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Closed - Loss',
#               'type': 'scatter',
#               'uid': '7c95c282-3779-4d50-b729-ec472ffcbbd0',
#               'x': array([datetime.datetime(2024, 12, 5, 0, 15),
#                           datetime.datetime(2024, 12, 5, 0, 45),
#                           datetime.datetime(2024, 12, 5, 2, 45),
#                           datetime.datetime(2024, 12, 5, 16, 15),
#                           datetime.datetime(2024, 12, 6, 6, 30),
#                           datetime.datetime(2024, 12, 6, 18, 0),
#                           datetime.datetime(2024, 12, 7, 1, 0),
#                           datetime.datetime(2024, 12, 7, 8, 45),
#                           datetime.datetime(2024, 12, 7, 19, 30),
#                           datetime.datetime(2024, 12, 7, 20, 15),
#                           datetime.datetime(2024, 12, 8, 0, 15),
#                           datetime.datetime(2024, 12, 8, 1, 0),
#                           datetime.datetime(2024, 12, 9, 6, 45),
#                           datetime.datetime(2024, 12, 9, 8, 30),
#                           datetime.datetime(2024, 12, 9, 18, 45),
#                           datetime.datetime(2024, 12, 10, 11, 15),
#                           datetime.datetime(2024, 12, 10, 12, 30)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([-0.00452775, -0.00911433, -0.03411224, -0.00769747, -0.0001083 ,
#                           -0.03944679, -0.01553017, -0.00471127, -0.01090356, -0.00376544,
#                           -0.00021179, -0.00253486, -0.00362298, -0.00791869, -0.01995034,
#                           -0.00928432, -0.00872652]),
#               'yaxis': 'y3'},
#              {'customdata': array([[ 3.00000000e+01,  3.00000000e+01, -1.11190198e-01, -1.14295872e-03]]),
#               'hovertemplate': ('Exit Trade Id: %{customdata[0]' ... 'r>Return: %{customdata[3]:.2%}'),
#               'legendgroup': '9',
#               'marker': {'color': '#FFAA00',
#                          'line': {'color': 'rgb(178,118,0)', 'width': 1},
#                          'opacity': array([0.7539452]),
#                          'size': array([7.1841092]),
#                          'symbol': 'circle'},
#               'mode': 'markers',
#               'name': 'Open',
#               'type': 'scatter',
#               'uid': '5d299193-fee4-4cb1-af71-8bd84ec0de48',
#               'x': array([datetime.datetime(2024, 12, 10, 23, 45)], dtype=object),
#               'xaxis': 'x3',
#               'y': array([-0.00114296]),
#               'yaxis': 'y3'},
#              {'legendgroup': '10',
#               'line': {'color': '#7f7f7f'},
#               'name': 'Benchmark',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'f61f269d-1c08-495f-ac3d-74fcef75ec2f',
#               'x': array([datetime.datetime(2024, 12, 4, 0, 0),
#                           datetime.datetime(2024, 12, 4, 0, 15),
#                           datetime.datetime(2024, 12, 4, 0, 30), ...,
#                           datetime.datetime(2024, 12, 10, 23, 15),
#                           datetime.datetime(2024, 12, 10, 23, 30),
#                           datetime.datetime(2024, 12, 10, 23, 45)], dtype=object),
#               'xaxis': 'x4',
#               'y': array([1.        , 0.99948418, 0.99687724, ..., 1.01048574, 1.00820167,
#                           1.00669528]),
#               'yaxis': 'y4'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '11',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '5bc28a6f-a4b9-4426-a2a1-cc18b4d84100',
#               'x': array([datetime.datetime(2024, 12, 4, 0, 0),
#                           datetime.datetime(2024, 12, 4, 0, 15),
#                           datetime.datetime(2024, 12, 4, 0, 30), ...,
#                           datetime.datetime(2024, 12, 10, 23, 15),
#                           datetime.datetime(2024, 12, 10, 23, 30),
#                           datetime.datetime(2024, 12, 10, 23, 45)], dtype=object),
#               'xaxis': 'x4',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y4'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(0, 128, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '11',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'a3542ae7-3d96-431b-888a-e73308ea8d76',
#               'x': array([datetime.datetime(2024, 12, 4, 0, 0),
#                           datetime.datetime(2024, 12, 4, 0, 15),
#                           datetime.datetime(2024, 12, 4, 0, 30), ...,
#                           datetime.datetime(2024, 12, 10, 23, 15),
#                           datetime.datetime(2024, 12, 10, 23, 30),
#                           datetime.datetime(2024, 12, 10, 23, 45)], dtype=object),
#               'xaxis': 'x4',
#               'y': array([1., 1., 1., ..., 1., 1., 1.]),
#               'yaxis': 'y4'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '11',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '0a30e1b5-5490-4967-bcce-289aa44124b3',
#               'x': array([datetime.datetime(2024, 12, 4, 0, 0),
#                           datetime.datetime(2024, 12, 4, 0, 15),
#                           datetime.datetime(2024, 12, 4, 0, 30), ...,
#                           datetime.datetime(2024, 12, 10, 23, 15),
#                           datetime.datetime(2024, 12, 10, 23, 30),
#                           datetime.datetime(2024, 12, 10, 23, 45)], dtype=object),
#               'xaxis': 'x4',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y4'},
#              {'connectgaps': False,
#               'fill': 'tonexty',
#               'fillcolor': 'rgba(255, 0, 0, 0.3)',
#               'hoverinfo': 'skip',
#               'legendgroup': '11',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': 'ac1c48b5-4c06-4b9c-a1dc-7c79df5018d0',
#               'x': array([datetime.datetime(2024, 12, 4, 0, 0),
#                           datetime.datetime(2024, 12, 4, 0, 15),
#                           datetime.datetime(2024, 12, 4, 0, 30), ...,
#                           datetime.datetime(2024, 12, 10, 23, 15),
#                           datetime.datetime(2024, 12, 10, 23, 30),
#                           datetime.datetime(2024, 12, 10, 23, 45)], dtype=object),
#               'xaxis': 'x4',
#               'y': array([1.        , 1.        , 1.        , ..., 0.96902524, 0.97123278,
#                           0.9726887 ]),
#               'yaxis': 'y4'},
#              {'legendgroup': '12',
#               'line': {'color': '#9467bd'},
#               'name': 'Value',
#               'showlegend': True,
#               'type': 'scatter',
#               'uid': 'e9a57966-1a23-4e90-a9fb-eab9e5b08c89',
#               'x': array([datetime.datetime(2024, 12, 4, 0, 0),
#                           datetime.datetime(2024, 12, 4, 0, 15),
#                           datetime.datetime(2024, 12, 4, 0, 30), ...,
#                           datetime.datetime(2024, 12, 10, 23, 15),
#                           datetime.datetime(2024, 12, 10, 23, 30),
#                           datetime.datetime(2024, 12, 10, 23, 45)], dtype=object),
#               'xaxis': 'x4',
#               'y': array([1.        , 1.        , 1.        , ..., 0.96902524, 0.97123278,
#                           0.9726887 ]),
#               'yaxis': 'y4'},
#              {'hoverinfo': 'skip',
#               'legendgroup': '11',
#               'line': {'color': 'rgba(0, 0, 0, 0)', 'width': 0},
#               'opacity': 0.0,
#               'showlegend': False,
#               'type': 'scatter',
#               'uid': '4ac3b947-4b47-48b5-b529-13b15097a169',
#               'x': array([datetime.datetime(2024, 12, 4, 0, 0),
#                           datetime.datetime(2024, 12, 4, 0, 15),
#                           datetime.datetime(2024, 12, 4, 0, 30), ...,
#                           datetime.datetime(2024, 12, 10, 23, 15),
#                           datetime.datetime(2024, 12, 10, 23, 30),
#                           datetime.datetime(2024, 12, 10, 23, 45)], dtype=object),
#               'xaxis': 'x4',
#               'y': array([1, 1, 1, ..., 1, 1, 1]),
#               'yaxis': 'y4'}],
#     'layout': {'annotations': [{'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trades',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 1.0,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Orders',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.742,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Trade PnL',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.484,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'},
#                                {'font': {'size': 16},
#                                 'showarrow': False,
#                                 'text': 'Cumulative Returns',
#                                 'x': 0.5,
#                                 'xanchor': 'center',
#                                 'xref': 'paper',
#                                 'y': 0.226,
#                                 'yanchor': 'bottom',
#                                 'yref': 'paper'}],
#                'height': 1250,
#                'legend': {'orientation': 'h',
#                           'traceorder': 'normal',
#                           'x': 1,
#                           'xanchor': 'right',
#                           'y': 1.032,
#                           'yanchor': 'bottom'},
#                'margin': {'b': 30, 'l': 30, 'r': 30, 't': 30},
#                'shapes': [{'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-04 08:45:00'),
#                            'x1': Timestamp('2024-12-04 13:45:00'),
#                            'xref': 'x',
#                            'y0': 96677.8269609375,
#                            'y1': 95842.4341875,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-04 13:45:00'),
#                            'x1': Timestamp('2024-12-04 21:00:00'),
#                            'xref': 'x',
#                            'y0': 95842.4341875,
#                            'y1': 98766.8296171875,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-05 02:45:00'),
#                            'x1': Timestamp('2024-12-05 03:45:00'),
#                            'xref': 'x',
#                            'y0': 101464.93388281249,
#                            'y1': 102986.9490234375,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-05 03:45:00'),
#                            'x1': Timestamp('2024-12-05 06:30:00'),
#                            'xref': 'x',
#                            'y0': 102986.9490234375,
#                            'y1': 102058.597265625,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-05 16:15:00'),
#                            'x1': Timestamp('2024-12-06 03:45:00'),
#                            'xref': 'x',
#                            'y0': 101476.5390703125,
#                            'y1': 97819.5421328125,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-07 01:00:00'),
#                            'x1': Timestamp('2024-12-07 05:00:00'),
#                            'xref': 'x',
#                            'y0': 100294.0664765625,
#                            'y1': 99752.29326562499,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-08 01:00:00'),
#                            'x1': Timestamp('2024-12-08 11:15:00'),
#                            'xref': 'x',
#                            'y0': 99956.5293515625,
#                            'y1': 99612.39569531249,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-08 11:15:00'),
#                            'x1': Timestamp('2024-12-08 14:30:00'),
#                            'xref': 'x',
#                            'y0': 99612.39569531249,
#                            'y1': 99981.0516796875,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-08 14:30:00'),
#                            'x1': Timestamp('2024-12-09 03:45:00'),
#                            'xref': 'x',
#                            'y0': 99981.0516796875,
#                            'y1': 99199.49101562498,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-09 18:45:00'),
#                            'x1': Timestamp('2024-12-09 21:00:00'),
#                            'xref': 'x',
#                            'y0': 97833.84946875,
#                            'y1': 96538.49674218749,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-09 21:00:00'),
#                            'x1': Timestamp('2024-12-10 06:30:00'),
#                            'xref': 'x',
#                            'y0': 96538.49674218749,
#                            'y1': 97103.1199921875,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-10 12:30:00'),
#                            'x1': Timestamp('2024-12-10 18:00:00'),
#                            'xref': 'x',
#                            'y0': 97151.1656484375,
#                            'y1': 94674.96319531249,
#                            'yref': 'y'},
#                           {'fillcolor': 'green',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-10 18:00:00'),
#                            'x1': Timestamp('2024-12-10 22:00:00'),
#                            'xref': 'x',
#                            'y0': 94674.96319531249,
#                            'y1': 96668.094515625,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-04 21:00:00'),
#                            'x1': Timestamp('2024-12-05 00:15:00'),
#                            'xref': 'x',
#                            'y0': 98766.8296171875,
#                            'y1': 99016.2376328125,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-05 00:15:00'),
#                            'x1': Timestamp('2024-12-05 00:45:00'),
#                            'xref': 'x',
#                            'y0': 99016.2376328125,
#                            'y1': 98311.0983046875,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-05 00:45:00'),
#                            'x1': Timestamp('2024-12-05 02:45:00'),
#                            'xref': 'x',
#                            'y0': 98311.0983046875,
#                            'y1': 101464.93388281249,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-05 06:30:00'),
#                            'x1': Timestamp('2024-12-05 16:15:00'),
#                            'xref': 'x',
#                            'y0': 102058.597265625,
#                            'y1': 101476.5390703125,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-06 03:45:00'),
#                            'x1': Timestamp('2024-12-06 06:30:00'),
#                            'xref': 'x',
#                            'y0': 97819.5421328125,
#                            'y1': 98004.772125,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-06 06:30:00'),
#                            'x1': Timestamp('2024-12-06 18:00:00'),
#                            'xref': 'x',
#                            'y0': 98004.772125,
#                            'y1': 101671.0703125,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-06 18:00:00'),
#                            'x1': Timestamp('2024-12-07 01:00:00'),
#                            'xref': 'x',
#                            'y0': 101671.0703125,
#                            'y1': 100294.0664765625,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-07 05:00:00'),
#                            'x1': Timestamp('2024-12-07 08:45:00'),
#                            'xref': 'x',
#                            'y0': 99752.29326562499,
#                            'y1': 99481.5672890625,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-07 08:45:00'),
#                            'x1': Timestamp('2024-12-07 19:30:00'),
#                            'xref': 'x',
#                            'y0': 99481.5672890625,
#                            'y1': 100366.42240624999,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-07 19:30:00'),
#                            'x1': Timestamp('2024-12-07 20:15:00'),
#                            'xref': 'x',
#                            'y0': 100366.42240624999,
#                            'y1': 100189.05440625,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-07 20:15:00'),
#                            'x1': Timestamp('2024-12-08 00:15:00'),
#                            'xref': 'x',
#                            'y0': 100189.05440625,
#                            'y1': 100010.07422656249,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-08 00:15:00'),
#                            'x1': Timestamp('2024-12-08 01:00:00'),
#                            'xref': 'x',
#                            'y0': 100010.07422656249,
#                            'y1': 99956.5293515625,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-09 03:45:00'),
#                            'x1': Timestamp('2024-12-09 06:45:00'),
#                            'xref': 'x',
#                            'y0': 99199.49101562498,
#                            'y1': 99038.33128125,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-09 06:45:00'),
#                            'x1': Timestamp('2024-12-09 08:30:00'),
#                            'xref': 'x',
#                            'y0': 99038.33128125,
#                            'y1': 99623.92283593748,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-09 08:30:00'),
#                            'x1': Timestamp('2024-12-09 18:45:00'),
#                            'xref': 'x',
#                            'y0': 99623.92283593748,
#                            'y1': 97833.84946875,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-10 06:30:00'),
#                            'x1': Timestamp('2024-12-10 11:15:00'),
#                            'xref': 'x',
#                            'y0': 97103.1199921875,
#                            'y1': 97809.74328124999,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-10 11:15:00'),
#                            'x1': Timestamp('2024-12-10 12:30:00'),
#                            'xref': 'x',
#                            'y0': 97809.74328124999,
#                            'y1': 97151.1656484375,
#                            'yref': 'y'},
#                           {'fillcolor': 'red',
#                            'layer': 'below',
#                            'line': {'width': 0},
#                            'opacity': 0.2,
#                            'type': 'rect',
#                            'x0': Timestamp('2024-12-10 22:00:00'),
#                            'x1': Timestamp('2024-12-10 23:45:00'),
#                            'xref': 'x',
#                            'y0': 96668.094515625,
#                            'y1': 96681.9140625,
#                            'yref': 'y'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 0,
#                            'y1': 0,
#                            'yref': 'y3'},
#                           {'line': {'color': 'gray', 'dash': 'dash'},
#                            'type': 'line',
#                            'x0': 0.0,
#                            'x1': 1.0,
#                            'xref': 'paper',
#                            'y0': 1,
#                            'y1': 1,
#                            'yref': 'y4'}],
#                'showlegend': True,
#                'template': '...',
#                'width': 750,
#                'xaxis': {'anchor': 'y', 'domain': [0.0, 1.0], 'matches': 'x4', 'showticklabels': False},
#                'xaxis2': {'anchor': 'y2', 'domain': [0.0, 1.0], 'matches': 'x4', 'showticklabels': False},
#                'xaxis3': {'anchor': 'y3', 'domain': [0.0, 1.0], 'matches': 'x4', 'showticklabels': False},
#                'xaxis4': {'anchor': 'y4', 'domain': [0.0, 1.0], 'title': {'text': 'Index'}},
#                'yaxis': {'anchor': 'x', 'domain': [0.774, 1.0], 'title': {'text': 'Price'}},
#                'yaxis2': {'anchor': 'x2', 'domain': [0.516, 0.742], 'title': {'text': 'Price'}},
#                'yaxis3': {'anchor': 'x3', 'domain': [0.258, 0.484], 'tickformat': '.2%', 'title': {'text': 'Trade PnL'}},
#                'yaxis4': {'anchor': 'x4', 'domain': [0.0, 0.226], 'title': {'text': 'Cumulative returns'}}}
# })
